# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/gloriajepkurui/Downloads/ housing project.csv')
df
# df.reset_index(inplace = True)... to reset indexing to the default indexing numbers
# Out:
#        UniqueID           ParcelID                  LandUse  \
# 0           2045   007 00 0 125.00            SINGLE FAMILY
# 1          16918   007 00 0 130.00            SINGLE FAMILY
# 2          54582   007 00 0 138.00            SINGLE FAMILY
# 3          43070   007 00 0 143.00            SINGLE FAMILY
# 4          22714   007 00 0 149.00            SINGLE FAMILY
# ...          ...               ...                      ...
# 56472      30469  188 10 0A 101.00            SINGLE FAMILY
# 56473      27707  188 10 0A 107.00            SINGLE FAMILY
# 56474      52709  188 10 0A 118.00  VACANT RESIDENTIAL LAND
# 56475      54042  188 10 0A 121.00  VACANT RESIDENTIAL LAND
# 56476      54043  188 10 0A 122.00  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress    SaleDate SalePrice  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE  2013-04-09    240000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE  2014-06-10    366000
# ...

# %%
#df.reset_index(inplace = True)
df
# Out:
#        level_0  index                           OwnerName  UniqueID   \
# 0            0      0           FRAZIER, CYRENTHA LYNETTE       2045
# 1            1      1             BONER, CHARLES & LESLIE      16918
# 2            2      2           WILSON, JAMES E. & JOANNE      54582
# 3            3      3            BAKER, JAY K. & SUSAN E.      43070
# 4            4      4  POST, CHRISTOPHER M. & SAMANTHA C.      22714
# ...        ...    ...                                 ...        ...
# 56472    56472  56472                                 NaN      30469
# 56473    56473  56473                                 NaN      27707
# 56474    56474  56474                                 NaN      52709
# 56475    56475  56475                                 NaN      54042
# 56476    56476  56476                                 NaN      54043
#
#                ParcelID                  LandUse  \
# 0       007 00 0 125.00            SINGLE FAMILY
# ...

# %%
df.iloc[7]
# Out:
# level_0                                                 7
# index                                                   7
# OwnerName                         BAILOR, DARRELL & TAMMY
# UniqueID                                            54583
# ParcelID                                  007 14 0 024.00
# LandUse                                     SINGLE FAMILY
# PropertyAddress        1917 GRACELAND  DR, GOODLETTSVILLE
# SaleDate                                       2016-09-27
# SalePrice                                          262000
# LegalReference                           20161005-0105441
# SoldAsVacant                                           No
# OwnerAddress       1917  GRACELAND DR, GOODLETTSVILLE, TN
# Acreage                                              1.03
# TaxDistrict                     GENERAL SERVICES DISTRICT
# LandValue                                         40000.0
# BuildingValue                                    157900.0
# ...

# %%
df.loc[2045]
# Out:
# level_0                                   2045
# index                                     2045
# OwnerName                                  NaN
# UniqueID                                 50666
# ParcelID                      043 10 0C 057.00
# LandUse                VACANT RESIDENTIAL LAND
# PropertyAddress    314 MCKENZIE  PASS, MADISON
# SaleDate                            2016-06-23
# SalePrice                               157000
# LegalReference                20160629-0066432
# SoldAsVacant                               Yes
# OwnerAddress                               NaN
# Acreage                                    NaN
# TaxDistrict                                NaN
# LandValue                                  NaN
# BuildingValue                              NaN
# TotalValue                                 NaN
# YearBuilt                                  NaN
# Bedrooms                                   NaN
# FullBath                                   NaN
# ...

# %%
df.set_index(['OwnerName', 'ParcelID'], inplace = True)
df
# Out:
#                                                      level_0  index  \
# OwnerName                          ParcelID
# FRAZIER, CYRENTHA LYNETTE          007 00 0 125.00         0      0
# BONER, CHARLES & LESLIE            007 00 0 130.00         1      1
# WILSON, JAMES E. & JOANNE          007 00 0 138.00         2      2
# BAKER, JAY K. & SUSAN E.           007 00 0 143.00         3      3
# POST, CHRISTOPHER M. & SAMANTHA C. 007 00 0 149.00         4      4
# ...                                                      ...    ...
# NaN                                188 10 0A 101.00    56472  56472
#                                    188 10 0A 107.00    56473  56473
#                                    188 10 0A 118.00    56474  56474
#                                    188 10 0A 121.00    56475  56475
#                                    188 10 0A 122.00    56476  56476
#
#                                                      UniqueID   \
# ...

# %%
df.sort_index()
# Out:
#                                                 level_0  index  UniqueID   \
# OwnerName                     ParcelID
# 1003 ELVIRA AVENUE TRUST, THE 072 06 0 088.00      8921   8921      36644
# 1015 32ND AVENUE TRUST, THE   092 01 0 126.00     19818  19818      41860
# 1025 SUMMITT, LLC             105 05 0 375.00     27778  27778      25923
# 1041 HICKORY HOLLOW TRUST     127 12 0 025.00     35341  35341      48650
# 1104 BERRY STREET TRUST, THE  044 15 0 246.00      2571   2571      42183
# ...                                                 ...    ...        ...
# NaN                           188 10 0A 101.00    56472  56472      30469
#                               188 10 0A 107.00    56473  56473      27707
#                               188 10 0A 118.00    56474  56474      52709
#                               188 10 0A 121.00    56475  56475      54042
#                               188 10 0A 122.00    56476  56476      54043
#
# ...
