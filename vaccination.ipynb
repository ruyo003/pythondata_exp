# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/gloriajepkurui/Downloads/vaccinations covid.csv")
pd.set_option('display.max.rows',300)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 355174 entries, 0 to 355173
# Data columns (total 45 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   iso_code                                    355174 non-null  object
#  1   continent                                   338302 non-null  object
#  2   location                                    355174 non-null  object
#  3   date                                        355174 non-null  object
#  4   new_tests                                   75403 non-null   float64
#  5   total_tests_per_thousand                    79387 non-null   float64
#  6   new_tests_per_thousand                      75403 non-null   float64
#  7   new_tests_smoothed                          103965 non-null  float64
#  8   new_tests_smoothed_per_thousand             103965 non-null  float64
# ...

# %%
df.shape
# Out:
# (355174, 45)

# %%
df.head(10)
# Out:
#   iso_code continent     location        date  new_tests  \
# 0      AFG      Asia  Afghanistan  03/01/2020        NaN
# 1      AFG      Asia  Afghanistan  04/01/2020        NaN
# 2      AFG      Asia  Afghanistan  05/01/2020        NaN
# 3      AFG      Asia  Afghanistan  06/01/2020        NaN
# 4      AFG      Asia  Afghanistan  07/01/2020        NaN
# 5      AFG      Asia  Afghanistan  08/01/2020        NaN
# 6      AFG      Asia  Afghanistan  09/01/2020        NaN
# 7      AFG      Asia  Afghanistan  10/01/2020        NaN
# 8      AFG      Asia  Afghanistan  11/01/2020        NaN
# 9      AFG      Asia  Afghanistan  12/01/2020        NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# ...

# %%
df.tail(2)
# Out:
#        iso_code continent  location        date  new_tests  \
# 355172      ZWE    Africa  Zimbabwe  07/11/2023        NaN
# 355173      ZWE    Africa  Zimbabwe  08/11/2023        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 355172                       NaN                     NaN                 NaN
# 355173                       NaN                     NaN                 NaN
#
#         new_tests_smoothed_per_thousand  positive_rate  ...  male_smokers  \
# 355172                              NaN            NaN  ...          30.7
# 355173                              NaN            NaN  ...          30.7
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 355172                 36.791                         1.7            61.49
# 355173                 36.791                         1.7            61.49
#
#         human_development_index  population  \
# 355172                    0.571    16320539
# ...

# %%
df['location']
# Out:
# 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 355169       Zimbabwe
# 355170       Zimbabwe
# 355171       Zimbabwe
# 355172       Zimbabwe
# 355173       Zimbabwe
# Name: location, Length: 355174, dtype: object

# %%
df.loc[0]
# [0] is the index, row of the data we are looking at
# Out:
# iso_code                                              AFG
# continent                                            Asia
# location                                      Afghanistan
# date                                           03/01/2020
# new_tests                                             NaN
# total_tests_per_thousand                              NaN
# new_tests_per_thousand                                NaN
# new_tests_smoothed                                    NaN
# new_tests_smoothed_per_thousand                       NaN
# positive_rate                                         NaN
# tests_per_case                                        NaN
# tests_units                                           NaN
# total_vaccinations                                    NaN
# people_vaccinated                                     NaN
# people_fully_vaccinated                               NaN
# total_boosters                                        NaN
# ...

# %%
 df[df['life_expectancy'] > 85]
# Out:
#        iso_code continent location        date  new_tests  \
# 203077      MCO    Europe   Monaco  03/01/2020        NaN
# 203078      MCO    Europe   Monaco  04/01/2020        NaN
# 203079      MCO    Europe   Monaco  05/01/2020        NaN
# 203080      MCO    Europe   Monaco  06/01/2020        NaN
# 203081      MCO    Europe   Monaco  07/01/2020        NaN
# ...         ...       ...      ...         ...        ...
# 204478      MCO    Europe   Monaco  04/11/2023        NaN
# 204479      MCO    Europe   Monaco  05/11/2023        NaN
# 204480      MCO    Europe   Monaco  06/11/2023        NaN
# 204481      MCO    Europe   Monaco  07/11/2023        NaN
# 204482      MCO    Europe   Monaco  08/11/2023        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 203077                       NaN                     NaN                 NaN
# 203078                       NaN                     NaN                 NaN
# ...

# %%
specific_continent = ['Asia','Europe']
df[df['continent'].isin(specific_continent)]
# Out:
#        iso_code continent     location        date  new_tests  \
# 0           AFG      Asia  Afghanistan  03/01/2020        NaN
# 1           AFG      Asia  Afghanistan  04/01/2020        NaN
# 2           AFG      Asia  Afghanistan  05/01/2020        NaN
# 3           AFG      Asia  Afghanistan  06/01/2020        NaN
# 4           AFG      Asia  Afghanistan  07/01/2020        NaN
# ...         ...       ...          ...         ...        ...
# 352357      YEM      Asia        Yemen  04/11/2023        NaN
# 352358      YEM      Asia        Yemen  05/11/2023        NaN
# 352359      YEM      Asia        Yemen  06/11/2023        NaN
# 352360      YEM      Asia        Yemen  07/11/2023        NaN
# 352361      YEM      Asia        Yemen  08/11/2023        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                            NaN                     NaN                 NaN
# ...

# %%
df[df['location'].str.contains('United')]
# Out:
#        iso_code      continent                      location        date  \
# 331479      ARE           Asia          United Arab Emirates  03/01/2020
# 331480      ARE           Asia          United Arab Emirates  04/01/2020
# 331481      ARE           Asia          United Arab Emirates  05/01/2020
# 331482      ARE           Asia          United Arab Emirates  06/01/2020
# 331483      ARE           Asia          United Arab Emirates  07/01/2020
# ...         ...            ...                           ...         ...
# 337098      VIR  North America  United States Virgin Islands  04/11/2023
# 337099      VIR  North America  United States Virgin Islands  05/11/2023
# 337100      VIR  North America  United States Virgin Islands  06/11/2023
# 337101      VIR  North America  United States Virgin Islands  07/11/2023
# 337102      VIR  North America  United States Virgin Islands  08/11/2023
#
#         new_tests  total_tests_per_thousand  new_tests_per_thousand  \
# ...

# %%
df2 = df.set_index('location')
df2
# Out:
#             iso_code continent        date  new_tests  \
# location
# Afghanistan      AFG      Asia  03/01/2020        NaN
# Afghanistan      AFG      Asia  04/01/2020        NaN
# Afghanistan      AFG      Asia  05/01/2020        NaN
# Afghanistan      AFG      Asia  06/01/2020        NaN
# Afghanistan      AFG      Asia  07/01/2020        NaN
# ...              ...       ...         ...        ...
# Zimbabwe         ZWE    Africa  04/11/2023        NaN
# Zimbabwe         ZWE    Africa  05/11/2023        NaN
# Zimbabwe         ZWE    Africa  06/11/2023        NaN
# Zimbabwe         ZWE    Africa  07/11/2023        NaN
# Zimbabwe         ZWE    Africa  08/11/2023        NaN
#
#              total_tests_per_thousand  new_tests_per_thousand  \
# location
# Afghanistan                       NaN                     NaN
# Afghanistan                       NaN                     NaN
# Afghanistan                       NaN                     NaN
# ...

# %%
df2.filter(items = ['continent','population'])
# Out:
#             continent  population
# location
# Afghanistan      Asia    41128772
# Afghanistan      Asia    41128772
# Afghanistan      Asia    41128772
# Afghanistan      Asia    41128772
# Afghanistan      Asia    41128772
# ...               ...         ...
# Zimbabwe       Africa    16320539
# Zimbabwe       Africa    16320539
# Zimbabwe       Africa    16320539
# Zimbabwe       Africa    16320539
# Zimbabwe       Africa    16320539
#
# [355174 rows x 2 columns]

# %%
df[df['life_expectancy'] > 60].sort_values(by = 'continent', ascending = False)
# Out:
#         iso_code      continent  location        date  new_tests  \
# 304795       SUR  South America  Suriname  12/10/2023        NaN
# 37217        BOL  South America   Bolivia  23/10/2021     6016.0
# 37215        BOL  South America   Bolivia  21/10/2021     6119.0
# 37214        BOL  South America   Bolivia  20/10/2021     6072.0
# 37213        BOL  South America   Bolivia  19/10/2021     6511.0
# ...          ...            ...       ...         ...        ...
# 350951  OWID_WRL            NaN     World  04/11/2023        NaN
# 350952  OWID_WRL            NaN     World  05/11/2023        NaN
# 350953  OWID_WRL            NaN     World  06/11/2023        NaN
# 350954  OWID_WRL            NaN     World  07/11/2023        NaN
# 350955  OWID_WRL            NaN     World  08/11/2023        NaN
#
#         total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 304795                       NaN                     NaN                 NaN
# ...
